# %%
# 何も考えず実行
import os
from PIL import Image
from google.colab import drive,files
drive.mount("/content/drive")

# 下にURLが出現するのでアプリケーションを認証し、パスコードを入力する
# もしくはGoogleドライブに接続していいか許可を求められるので、許可する

# %%
# リサイズしたい画像素材の保存先を指定する
# マスタとなる1500x1500の画像ファイル名は、01.png〜のように付番し命名しておく
dir_name = "/content/drive/#####/master"

# リサイズした画像の格納先を指定する
# new_dir_name_600 = "/content/drive/#####/600_600"
# new_dir_name_300 = "/content/drive/#####/300_300"
new_dir_name_750 = "/content/drive/#####/750_600"
# new_dir_name_443 = "/content/drive/#####/443_443"
# new_dir_name_196 = "/content/drive/#####/196_196"
# new_dir_name_98 = "/content/drive/#####/98_98"

# 名前を入力する（）
# new_fes_name = ""
# 日付を入力する（）
new_file_date = ""

files = os.listdir(dir_name)
for file in files:
    try:
        print("---------------------")
        print("start %s" % (file))
        photo = Image.open(os.path.join(dir_name, file))
        new_file_name = file.split('.')

        # #600_600
        # if os.path.exists(new_dir_name_600):
        #     photo_resize_name_600 = "%s%s.%s" % (new_fes_name, new_file_name[0], new_file_name[1])
        #     print(photo_resize_name_600)
        #     photo_resize_600 = photo.resize((600, 600), Image.LANCZOS)
        #     photo_resize_600.save((os.path.join(new_dir_name_600, photo_resize_name_600)), quality=95)

        # #300_300
        # if os.path.exists(new_dir_name_300):
        #     photo_resize_name_300 = "%s%s_m.%s" % (new_fes_name, new_file_name[0], new_file_name[1])
        #     print(photo_resize_name_300)
        #     photo_resize_300 = photo.resize((300, 300), Image.LANCZOS)
        #     photo_resize_300.save((os.path.join(new_dir_name_300, photo_resize_name_300)), quality=95)

        # #98_98 pre
        # if os.path.exists(new_dir_name_98):
        #     photo_resize_name_98 = "%s%s_s.%s" % (new_fes_name, new_file_name[0], new_file_name[1])
        #     print(photo_resize_name_98)
        #     photo_resize_98 = photo.resize((98, 98), Image.LANCZOS)
        #     photo_resize_98.save((os.path.join(new_dir_name_98, photo_resize_name_98)), quality=95)
        #     print("complete %s" % (file))

        #750_600
        if os.path.exists(new_dir_name_750):
           photo_resize_name_750 = "%s_%s.%s" % (new_file_name[0], new_file_date, new_file_name[1])
           print(photo_resize_name_750)
           photo_resize_750_resize = photo.resize((750, 750), Image.LANCZOS)
           box = (0, 75, 750, 675)
           photo_resize_750 = photo_resize_750_resize.crop(box)
           photo_resize_750.save((os.path.join(new_dir_name_750, photo_resize_name_750)), quality=95)

        # #443_443
        # if os.path.exists(new_dir_name_443):
        #     photo_resize_name_443 = "%s_%s_443_443.%s" % (new_fes_name, new_file_name[0], new_file_name[1])
        #     print(photo_resize_name_443)
        #     photo_resize_443 = photo.resize((443, 443), Image.LANCZOS)
        #     photo_resize_443.save((os.path.join(new_dir_name_443, photo_resize_name_443)), quality=95)

        # #196_196
        # if os.path.exists(new_dir_name_196):
        #     photo_resize_name_196 = "%s_%s_196_196.%s" % (new_fes_name, new_file_name[0], new_file_name[1])
        #     print(photo_resize_name_196)
        #     photo_resize_196 = photo.resize((196, 196), Image.LANCZOS)
        #     photo_resize_196.save((os.path.join(new_dir_name_196, photo_resize_name_196)), quality=95)

        #98_98 mail
        # if os.path.exists(new_dir_name_98):
        #     photo_resize_name_98 = "%s_%s_98_98.%s" % (new_fes_name, new_file_name[0], new_file_name[1])
        #     print(photo_resize_name_98)
        #     photo_resize_98 = photo.resize((98, 98), Image.LANCZOS)
        #     photo_resize_98.save((os.path.join(new_dir_name_98, photo_resize_name_98)), quality=95)
        #     print("complete %s" % (file))
    except:
        print("処理が途中で失敗しました。もう一度実行してください")
